# %% [markdown]
# 📌 Matplotlib
# Matplotlib es la biblioteca principal de visualización en Python. Proporciona una gran flexibilidad para crear gráficos de distintos tipos, como gráficos de líneas, dispersión, histogramas, barras, etc.
#
# Elementos clave de Matplotlib
# 1. pyplot: Es un módulo de Matplotlib que facilita la creación de gráficos con una sintaxis similar a MATLAB.
# 2. Figura (Figure): Es el contenedor principal de la visualización.
# 3. Ejes (Axes): Son los sistemas de coordenadas dentro de una figura donde se colocan los gráficos.
# 4. Títulos y etiquetas: Se pueden agregar títulos y etiquetas a los ejes con plt.title(), plt.xlabel(), plt.ylabel().
# 5. Leyendas: Se usa plt.legend() para mostrar etiquetas en los gráficos.
#
# Ejemplo básico de Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Crear la figura y los ejers
plt.figure(figsize=(8,5))

# Crear el gráfico
plt.plot(x, y, label='seno', color='b', linestyle='--')

# Añadir titulo
plt.title('Gráfico de la función seno')
plt.xlabel('Eje X')
plt.ylabel('Eje Y')

plt.legend()
plt.grid(True)

# Mostrar gráfico
plt.show()

# %% [markdown]
# 📌 Seaborn
# Seaborn es una biblioteca basada en Matplotlib que simplifica la visualización de datos y añade funcionalidades avanzadas.
#
# Características principales
# 1. Estilo mejorado: Seaborn ofrece gráficos más atractivos con menos configuración.
# 2. Facilidad de uso: Permite crear gráficos complejos con menos código.
# 3. Soporte para DataFrames de Pandas: Se integra bien con Pandas para graficar directamente desde DataFrames.
# 4. Gráficos estadísticos: Incluye gráficos como histogramas, boxplots y gráficos de regresión.
#
# Ejemplo básico de Seaborn

# %%
import pandas as pd
import seaborn as sns

# Crear un DatFrame de ejemplo
np.random.seed(42)
data = pd.DataFrame({
    'Categoria': ['A', 'B', 'C', 'D', 'E'],
    'Valor 1': np.random.randn(5),
})

# Configurar estilo
sns.set_style('whitegrid')

# Crear un boxplot
plt.figure(figsize=(8,5))
sns.boxplot(x='Categoria', y='Valor 1', data=data, palette='coolwarm')

# Agregar tittulo
plt.title('Dsitribución de la variable por categoría')

#Mostrar gráfico
plt.show()
# Out:
# C:\Users\52771\AppData\Local\Temp\ipykernel_14252\2502229623.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Categoria', y='Valor 1', data=data, palette='coolwarm')
